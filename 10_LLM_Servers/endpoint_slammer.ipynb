# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Ah, the age‑old riddle that has kept linguists, comedians, and coffee lovers on the edge of their seats for centuries!  Let’s unpack it—and maybe sprinkle in a dash of science, a pinch of folklore, and a spoonful of good‑ol’ humor.
#
# ---
#
# ## 1. The Classic Lines
#
# > **“How much wood could a wood‑chuck chuck if a wood‑chuck could chuck wood?”**
#
# - **Tongue‑twister?** Yes.
# - **A-ha, a math problem?** Touche.
# - **A challenge to your sense of rhythm?** Absolutely.
#
# ---
#
# ## 2. The “Real” Woodchuck (Marmot Lettuce-Explorer)
#
# ### What a woodchuck (groundhog) actually does:
#
# | Activity | How it goes | “Wood‑creting” amount |
# |----------|-------------|-----------------------|
# | **Burrowing** | Chases soil, not saplings | 0 lb of *tree* wood |
# | **Root‑gardening** | Eats all kinds of greens | 0 lb of *oak* logs |
# | **Frolicking** | Chews on boulders, not branches | 0 lb of *timber* |
#
# The **Montreal Institute for Bi-Atomic Tim.** (metaphorical) actually conducted a study in 1976:
#
# > > *“If a woodchuck could chuck wood, it would probably spend a third of its daytime looking for it and the remaining two-thirds trying to lift a gardening trowel. The amount of wooden material could theoretically be about 700 lbs, but that’s assuming the groundhog took on the role of a full‑time lumberjack.”*
#
# So, responded academically: *Approximately 700 lbs.* (with the caveat that groundhogs aren’t professional wood movers).
#
# ---
#
# ## 3. The Legendary “Chuck” Quantities
#
# | Source | Answer | Roughness? |
# |--------|--------|------------|
# | **Ernest Hemingway’s “Woodchuck Vlog”** | 0 lb | They’re famous for nothing. |
# | **The University of Vermont Nanopaper** | 52.5 lbs/flight | Imagining a woodchuck jet‑plane. |
# | **The 1935 ‘Woodchuck & Co.’ Study** | 700 lbs | Based on a 30‑minutes workout using *ESQ™* (Energy‑Summoning Quantum). |
#
# ### The Bottom Line
#
# If a woodchuck had a dream job as a stump-attractor: **about 700 pounds** of wood piled within a kilometer-range by the time the sun goes down.
#
# ---
#
# ## 4. Practical Take‑aways
#
# - **Real Woodchuck**: 0 pounds.
# - **Mystical Woodchuck**: ~700 pounds.
# - **If you’re a lumberjack**: Maybe misplace 700 lbs and call it “schrodinger wood.”
#
# ---
#
# ## 5. A Quick “If-Then” for Real Life
#
# | Scenario | Where You Are | What to Do |
# |----------|--------------|------------|
# | **You’re building a treehouse** | Need the wood? | Call the local lumber yard—woodchucks aren’t the right choice. |
# | **You’re a philosopher on a rainy day** | Reflecting on life’s paradoxes | Chant the tongue‑twister backward for 12 minutes on a sound‑proofable pillow. |
# | **You’re a dad making jokes** | Want to embarrass your kids | Stick with (or add) the *“How many sparrows can a lumber‑bird carry while in a repetitive motion…”*. |
#
# ---
#
# ## 6. TL;DR
#
# A woodchuck would chuck **zero** because it’s a burrowing groundhog who admires salad more than sap. | To give it a mythical career, astronomers estimate **about 700 lb** of wood—like a lumberjack on a 30‑minute sprint. | Either way, the real answer is that **woodchucks didn’t evolve to chuck wood**; it was just a fun way to get us to work on syllables.
#
# ---
#
# Thanks for asking! May your tongue stay tight, your chucking ambitions be grounded, and your why‑just‑asked‑json-requests always be followed by a laugh.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 22: A wood‑chuck, if it were truly a wood‑chuck, might chuck **a...
# Response 14: The classic tongue‑twister is all about the *possible* amoun...
# Response 2: In truth, the folklore answer is the joke itself:
#
# > “How mu...
# Response 17: In the classic tongue‑twister, the “woodchuck” (or *groundho...
# Response 3: Ah, the classic tongue‑twister! While there's no hard‑scient...
# Response 15: The classic nursery rhyme itself never gives a precise numbe...
# Response 12: If a wood‑chuck could chuck, it would chuck as *much* wood a...
# Response 23: **Answer:**
# The classic tongue‑twister doesn't have a prec...
# Response 5: There’s no hard‑and‑fast rule for a wood‑chuck’s lumber‑lift...
# Response 10: **Answer (Request 10)**
#
# A classic “tongue‑twister” rather...
# Response 1: Here’s the classic answer plus a bit of science‑style trivia...
# Response 6: It’s a classic tongue‑twister, and the answer is as much fun...
# Response 24: **Answer to the classic tongue‑twister:**
#
# > *“How much wood...
# Response 8: A classic tongue‑twister answer already exists:
#
# > “A wood...
# Response 11: It isn’t a science‑B. in fact no wood‑chuck (groundhog) real...
# Response 13: **Answer (Request 13)**
#
# The tongue‑twister *“How much wood ...
# Response 20: **Answer: The classic tongue‑twister answer**
#
# > *“A woodchu...
# Response 21: A classic tongue‑twister to a charming, if nãoserious, answe...
# Response 4: The classic answer goes: **“A woodchuck would chuck as much ...
# Response 7: A wood‑chuck—if it actually had the urge and the strength to...
# Response 9: **A playful estimate: about 700–800 pounds of wood a day (ro...
# Response 18: A wood‑chuck would, in theory, chuck as much as its little p...
# Response 16: It’s the classic tongue‑twister that’s been puzzling linguis...
# Response 19: The old tongue‑twister isn’t really a science question—it’s ...
